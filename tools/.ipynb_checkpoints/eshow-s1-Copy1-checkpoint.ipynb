# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy import nan
# %run opentable.ipynb
plt.rcParams["figure.figsize"] = (15,2)



path_order = "/data2/run/highres.s/data/orders.csv"
path_nps = "/data2/run/highres.s/data/nps.csv"

sids = [
    {"exchange":"okxswap", "sid":0},
    {"exchange":"binanceswap", "sid":1},
    {"exchange":"bybitswap", "sid":2},
    {"exchange":"binancespot", "sid":3},
    {"exchange":"okxspot", "sid":4}
]

ks_file = [
    {"exchange":"okxswap", "ttype":"maker", "fee":-0},
    {"exchange":"okxswap", "ttype":"taker", "fee":0.00015},
    {"exchange":"binanceswap", "ttype":"maker", "fee":-0.00005},
    {"exchange":"binanceswap", "ttype":"taker", "fee":0.00015},
    {"exchange":"bybitswap", "ttype":"maker", "fee":-0.0001},
    {"exchange":"bybitswap", "ttype":"taker", "fee":0.00025},
    {"exchange":"binancespot", "ttype":"maker", "fee":-0.00004},
    {"exchange":"binancespot", "ttype":"taker", "fee":0.00018},
    {"exchange":"okxspot", "ttype":"maker", "fee":-0.00005},
    {"exchange":"okxspot", "ttype":"taker", "fee":0.0002},
]


ks_file = [
    {"exchange":"okxswap", "ttype":"maker", "fee":-0.00005},
    {"exchange":"okxswap", "ttype":"taker", "fee":0.00015},
    {"exchange":"binanceswap", "ttype":"maker", "fee":0},
    {"exchange":"binanceswap", "ttype":"taker", "fee":0.00015},
    {"exchange":"bybitswap", "ttype":"maker", "fee":0},
    {"exchange":"bybitswap", "ttype":"taker", "fee":0.00025},
    {"exchange":"binancespot", "ttype":"maker", "fee":0},
    {"exchange":"binancespot", "ttype":"taker", "fee":0.00018},
    {"exchange":"okxspot", "ttype":"maker", "fee":0},
    {"exchange":"okxspot", "ttype":"taker", "fee":0.0002},
]

# %%
norder = pd.read_csv(path_order, header = None)
norder.head()
# Out:
#                  0              1              2                 3        4   \
# 0  ask_m_3_0.0004_8  1702252804000  1702252807116  ask_m_3_0.0004_8  SOLUSDT
# 1  ask_m_3_0.0004_8  1702252804000  1702252807116  ask_m_3_0.0004_8  SOLUSDT
# 2  ask_m_3_0.0004_8  1702252804000  1702252807116  ask_m_3_0.0004_8  SOLUSDT
# 3  ask_m_4_0.0004_3  1702252801000  1702252807209  ask_m_4_0.0004_3  SOLUSDT
# 4  ask_m_4_0.0004_3  1702252801000  1702252807209  ask_m_4_0.0004_3  SOLUSDT
#
#       5   6     7      8         9         10              11        12  \
# 0  maker   3  sell  74.91  1.068447  0.285488  partial_filled  5.524512
# 1  maker   3  sell  74.91  1.068447  0.560000  partial_filled  5.524512
# 2  maker   3  sell  74.91  1.068447  0.222959          filled  5.524512
# 3  maker   4  sell  74.91  1.068519  0.055160  partial_filled  0.000000
# 4  maker   4  sell  74.91  1.068519  0.400000  partial_filled  0.000000
#
#            13          14     15    16
# 0  283.630000  ask:0.0004  74.89  74.9
# 1  283.630000  ask:0.0004  74.89  74.9
# 2  283.630000  ask:0.0004  74.89  74.9
# 3   26.517578  ask:0.0004  74.89  74.9
# 4   26.517578  ask:0.0004  74.89  74.9

# %%
norder.columns = ["oid", "cts", "uts", "oid2", "symbol", "ttype", "sid", "side", "price", "amount", "famount", "status", "inpos", "tlen","bid1","ask1","fkey"]
norder = norder[norder["symbol"] == "DOGEUSDT"]
norder.groupby("symbol").count()
# Out:
#             oid    cts    uts   oid2  ttype    sid   side  price  amount  \
# symbol
# DOGEUSDT  24174  24174  24174  24174  24174  24174  24174  24174   24174
#
#           famount  status  inpos   tlen   bid1   ask1   fkey
# symbol
# DOGEUSDT    24174   24174  24174  24174  24174  24174  24174

# %%
nsid = pd.DataFrame(sids)
norder = pd.merge(norder, pd.DataFrame(sids), on="sid", how="left")
norder = pd.merge(norder, pd.DataFrame(ks_file), on=["exchange", "ttype"], how="left").sort_values("uts").reset_index()

# %%
norder.head()
norder["amount_trade"] = norder["famount"]
norder["amountu"] = norder["amount_trade"] * norder["price"]
norder[norder["ttype"] == "maker"].head(10)
# Out:
#    index                    oid            cts            uts  \
# 0      0  bid_m_0_0.0002_683937  1702252850000  1702252861489
# 1      1  ask_m_1_0.0002_683948  1702252866000  1702252866871
# 2      2  ask_m_1_0.0002_683948  1702252866000  1702252866871
# 3      3  ask_m_1_0.0002_683948  1702252866000  1702252866871
# 4      4  ask_m_1_0.0002_683948  1702252866000  1702252866871
# 5      5  ask_m_1_0.0002_683948  1702252866000  1702252866871
# 6      6  ask_m_1_0.0002_683948  1702252866000  1702252866871
# 7      7  ask_m_1_0.0002_684023  1702252984000  1702252987433
# 8      8  ask_m_1_0.0004_684019  1702252976000  1702252987442
# 9      9  bid_m_3_0.0002_684030  1702252988000  1702252990689
#
#                     oid2    symbol  ttype  sid  side    price    ...      \
# 0  bid_m_0_0.0002_683937  DOGEUSDT  maker    0   buy  0.10185    ...
# 1  ask_m_1_0.0002_683948  DOGEUSDT  maker    1  sell  0.10194    ...
# 2  ask_m_1_0.0002_683948  DOGEUSDT  maker    1  sell  0.10194    ...
# 3  ask_m_1_0.0002_683948  DOGEUSDT  maker    1  sell  0.10194    ...
# 4  ask_m_1_0.0002_683948  DOGEUSDT  maker    1  sell  0.10194    ...
# 5  ask_m_1_0.0002_683948  DOGEUSDT  maker    1  sell  0.10194    ...
# 6  ask_m_1_0.0002_683948  DOGEUSDT  maker    1  sell  0.10194    ...
# 7  ask_m_1_0.0002_684023  DOGEUSDT  maker    1  sell  0.10214    ...
# 8  ask_m_1_0.0004_684019  DOGEUSDT  maker    1  sell  0.10215    ...
# 9  bid_m_3_0.0002_684030  DOGEUSDT  maker    3   buy  0.10199    ...
#
#            status          inpos      tlen        bid1     ask1     fkey  \
# 0          filled      53.251468     268.0  bid:0.0002  0.10190  0.10191
# 1  partial_filled       0.000000     701.0  ask:0.0002  0.10193  0.10194
# 2  partial_filled       0.000000     701.0  ask:0.0002  0.10193  0.10194
# 3  partial_filled       0.000000     701.0  ask:0.0002  0.10193  0.10194
# 4  partial_filled       0.000000     701.0  ask:0.0002  0.10193  0.10194
# 5  partial_filled       0.000000     701.0  ask:0.0002  0.10193  0.10194
# 6  partial_filled       0.000000     701.0  ask:0.0002  0.10193  0.10194
# 7          filled  278961.803825  347381.0  ask:0.0002  0.10210  0.10211
# 8          filled   49380.872194  133039.0  ask:0.0004  0.10214  0.10215
# 9          filled      81.000000  145155.0  bid:0.0002  0.10201  0.10202
#
#       exchange      fee amount_trade    amountu
# 0      okxswap -0.00005   785.198999  79.972518
# 1  binanceswap  0.00000   117.000000  11.926980
# 2  binanceswap  0.00000   116.000000  11.825040
# 3  binanceswap  0.00000   117.000000  11.926980
# 4  binanceswap  0.00000   117.000000  11.926980
# 5  binanceswap  0.00000   117.000000  11.926980
# 6  binanceswap  0.00000   117.000000  11.926980
# 7  binanceswap  0.00000   786.313807  80.314092
# 8  binanceswap  0.00000   786.390550  80.329795
# 9  binancespot  0.00000   833.815247  85.040817
#
# [10 rows x 22 columns]

# %%
norder.groupby("symbol").count()
# Out:
#           index    oid    cts    uts   oid2  ttype    sid   side  price  \
# symbol
# DOGEUSDT  24174  24174  24174  24174  24174  24174  24174  24174  24174
#
#           amount   ...     status  inpos   tlen   bid1   ask1   fkey  \
# symbol             ...
# DOGEUSDT   24174   ...      24174  24174  24174  24174  24174  24174
#
#           exchange    fee  amount_trade  amountu
# symbol
# DOGEUSDT     24174  24174         24174    24174
#
# [1 rows x 21 columns]

# %%
norder.groupby("ttype").sum()["amountu"]
# Out:
# ttype
# maker    996393.177556
# Name: amountu, dtype: float64

# %%
ot = Opentable()
pfix = 0
ps = []
poss = {0:0,1:0,2:0,3:0,4:0}


for row in norder.sort_values("cts").to_dict("records"):
    #if row["status"] == "partial_filled":continue
    
    if(row["side"] == "buy"):
        p = ot.add("bid", row["price"], row["amount_trade"], row["cts"])
        pfix+=p
        poss[row["sid"]]+=(row["price"] * row["amount_trade"])
        pfix-=(row["fee"] * row["price"] * row["amount_trade"])
    if(row["side"] == "sell"):
        p = ot.drop("ask", row["price"], row["amount_trade"], row["cts"])
        pfix+=p
        poss[row["sid"]]-=(row["price"] * row["amount_trade"])
        pfix-=(row["fee"] * row["price"] * row["amount_trade"])
    openrisk,_l,_l = ot.get_openrisk()
        
    ps.append({
        "ts":row["cts"],
        "pfix":pfix,
        "open":openrisk,
        "poss_0":poss[0],
        "poss_1":poss[1],
        "poss_2":poss[2],
        "poss_3":poss[3],
        "poss_4":poss[4],
    })

# %%
nps = pd.DataFrame(ps)
nps["dt"] = pd.to_datetime(nps["ts"] + 8*3600*1000, unit="ms")
nps.plot(x="dt", y="pfix")
nps.plot(x="dt", y="open")

# %%
norder["dt"] = pd.to_datetime(norder["uts"] + 8*3600*1000, unit="ms")
norder.plot(x="dt", y="ask1")

# %%
ax = nps.plot(x="dt", y="poss_0", label="0")
nps.plot(x="dt", y="poss_1", label="1", ax=ax)
nps.plot(x="dt", y="poss_2", label="2", ax=ax)
nps.plot(x="dt", y="poss_3", label="3", ax=ax)
nps.plot(x="dt", y="poss_4", label="4", ax=ax)

plt.legend()

# %%
nps = pd.read_csv(path_nps, header = None)
nps.columns = ["ts", "symbol", "sid", "pos", "open"]
nps["dt"] = pd.to_datetime(nps["ts"] + 8*3600*1000, unit="ms")

# %%
nps.plot(x="dt", y="open")

# %%
norder["amountu"].sum() / 2000/5,norder["amountu"].sum()
# Out:
# (99.63931775564542, 996393.1775564542)

# %%
# #read tick
# tickpath  ="/data2/zl/l2_trade/tickfactor/SOLUSDT.npy"
# ntick = np.load(tickpath, allow_pickle=True)
# cols = ["ts"]
# for ks in sids:
    
#     cols.append("f_"+str(ks["sid"]))
#     cols.append("s_"+str(ks["sid"]))
# dftick = pd.DataFrame(ntick)
# dftick.columns = cols
# dftick["dt"] = pd.to_datetime(dftick["ts"], unit="s")

# %%
# norder["dt"] = pd.to_datetime(norder["cts"], unit="ms")
# for ks in sids:
#     torder = norder[norder["sid"] == ks["sid"]]
#     torder.plot(x="dt", y="price")
